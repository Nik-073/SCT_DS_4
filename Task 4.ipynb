# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import  folium
from folium.plugins import HeatMap

# %%
df=pd.read_csv('/Users/nikhi/Downloads/US_Accidents_March23.csv')

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# ...

# %%
df = df.drop(['End_Lat', 'End_Lng', 'Wind_Chill(F)', 'Precipitation(in)'], axis=1)

# %%
for col in ['Temperature(F)','Humidity(%)','Pressure(in)','Visibility(mi)','Wind_Speed(mph)']:
    df[col]=df[col].fillna(df[col].mean())

# %%
for col in ['Street', 'Zipcode', 'Timezone', 'Airport_Code', 
            'Weather_Condition', 'Wind_Direction', 
            'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight']:
     df[col] = df[col].fillna(df[col].mode()[0])

# %%
df = df.dropna(subset=['Description'])

# %%
df.isnull().sum()
# Out:
# ID                            0
# Source                        0
# Severity                      0
# Start_Time                    0
# End_Time                      0
# Start_Lat                     0
# Start_Lng                     0
# Distance(mi)                  0
# Description                   0
# Street                        0
# City                        253
# County                        0
# State                         0
# Zipcode                       0
# Country                       0
# Timezone                      0
# Airport_Code                  0
# Weather_Timestamp        120228
# Temperature(F)                0
# Humidity(%)                   0
# Pressure(in)                  0
# Visibility(mi)                0
# Wind_Direction                0
# Wind_Speed(mph)               0
# Weather_Condition             0
# Amenity                       0
# Bump                          0
# Crossing                      0
# Give_Way                      0
# ...

# %%
print("Jupyter is working!")
# Out:
# Jupyter is working!

# %%
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  Distance(mi)  \
# 0  39.865147 -84.058723          0.01
# 1  39.928059 -82.831184          0.01
# 2  39.063148 -84.032608          0.01
# 3  39.747753 -84.205582          0.01
# 4  39.627781 -84.188354          0.01
#
#                                          Description  \
# 0  Right lane blocked due to accident on I-70 Eas...
# 1  Accident on Brice Rd at Tussing Rd. Expect del...
# 2  Accident on OH-32 State Route 32 Westbound at ...
# 3  Accident on I-75 Southbound at Exits 52 52B US...
# ...

# %%
df['City'] = df['City'].fillna('Unknown')

# %%
df = df.drop(columns=['Weather_Timestamp'])

# %%
df.isnull().sum()
# Out:
# ID                       0
# Source                   0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# Distance(mi)             0
# Description              0
# Street                   0
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Airport_Code             0
# Temperature(F)           0
# Humidity(%)              0
# Pressure(in)             0
# Visibility(mi)           0
# Wind_Direction           0
# Wind_Speed(mph)          0
# Weather_Condition        0
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# No_Exit                  0
# Railway                  0
# Roundabout               0
# Station                  0
# Stop                     0
# ...

# %%
df.dtypes
# Out:
# ID                        object
# Source                    object
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# Distance(mi)             float64
# Description               object
# Street                    object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Temperature(F)           float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# Wind_Direction            object
# Wind_Speed(mph)          float64
# Weather_Condition         object
# Amenity                     bool
# Bump                        bool
# Crossing                    bool
# Give_Way                    bool
# ...

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'], errors='coerce')
df['Hour'] = df['Start_Time'].dt.hour
df['DayOfWeek'] = df['Start_Time'].dt.day_name()
df['Month'] = df['Start_Time'].dt.month

# %%
df.dtypes
# Out:
# ID                               object
# Source                           object
# Severity                          int64
# Start_Time               datetime64[ns]
# End_Time                         object
# Start_Lat                       float64
# Start_Lng                       float64
# Distance(mi)                    float64
# Description                      object
# Street                           object
# City                             object
# County                           object
# State                            object
# Zipcode                          object
# Country                          object
# Timezone                         object
# Airport_Code                     object
# Temperature(F)                  float64
# Humidity(%)                     float64
# Pressure(in)                    float64
# Visibility(mi)                  float64
# Wind_Direction                   object
# Wind_Speed(mph)                 float64
# ...

# %%
# ------------------- ACCIDENTS BY TIME -------------------
plt.figure(figsize=(10,4))
sns.countplot(x='Hour', data=df)
plt.title('Accidents by Hour of Day')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(x='DayOfWeek', data=df, order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
plt.title('Accidents by Day of Week')
plt.show()

# %%
# ------------------- ACCIDENTS BY ROAD/STREET -------------------
top_streets = df['Street'].value_counts().head(10)
top_streets.plot(kind='bar', figsize=(8,4), color='skyblue')
plt.title('Top 10 Streets with Most Accidents')
plt.ylabel('Number of Accidents')
plt.show()

# %%
# ------------------- ACCIDENT SEVERITY -------------------
plt.figure(figsize=(8,4))
sns.countplot(x='Severity', data=df)
plt.title('Accident Severity Distribution')
plt.show()

# %%
# Severity vs Distance
plt.figure(figsize=(8,4))
sns.boxplot(x='Severity', y='Distance(mi)', data=df)
plt.title('Severity vs Accident Distance')
plt.show()

# %%
# ------------------- ACCIDENT HOTSPOTS -------------------
# Map accidents
m = folium.Map(location=[df['Start_Lat'].mean(), df['Start_Lng'].mean()], zoom_start=6)
for i, row in df.iterrows():
    folium.CircleMarker(location=[row['Start_Lat'], row['Start_Lng']],
                        radius=2, color='red', fill=True).add_to(m)
# Save map
m.save('accident_map.html')

# %%
# Heatmap of accident locations
m_heat = folium.Map(location=[df['Start_Lat'].mean(), df['Start_Lng'].mean()], zoom_start=6)
heat_data = [[row['Start_Lat'], row['Start_Lng']] for index, row in df.iterrows()]
HeatMap(heat_data).add_to(m_heat)
m_heat.save('accident_heatmap.html')

# %%
# ------------------- CORRELATION HEATMAP -------------------
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Peak Times & Days: Accidents mostly occur in evening hours and are highest on Fridays.
#
# Hotspot Locations: Certain streets and areas account for a large number of accidents, highlighting high-risk zones.
#
# Severity & Safety Measures: Longer-distance accidents tend to be more severe; insights can guide traffic monitoring, road safety improvements, and preventive strategies.
